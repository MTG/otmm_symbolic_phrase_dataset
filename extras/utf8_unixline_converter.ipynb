# %%
import os
import subprocess
from fileoperations import getFileNamesInDir
import pdb

# %%
folder = '../annotations'
keyword = '*.txt'
files, dummy, names = getFileNamesInDir(folder, keyword=keyword)
names = [os.path.splitext(n)[0] for n in names]

# %%
iconv_map = {'utf-16le':'UTF-16LE','iso-8859-1':'ISO_8859-9','ISO-8859':'ISO_8859-9'}
for f,n in zip(files, names):
    try:  # unix
        out = subprocess.check_output("file -i " + f, shell = True)
        curr_charset = out.split('charset=')[1]

        if curr_charset.endswith('\n'):
            curr_charset = curr_charset[:-1]
            
        if not any(curr_charset in charset for charset in ['utf-8', 'us-ascii']):
            print curr_charset + '\t' + n
            commandstr = ("iconv -f " +  iconv_map[curr_charset] + " -t UTF-8 " + f + " > tmp.txt "
                          "&& mv -f tmp.txt " + f)
            out = subprocess.check_output(commandstr, shell = True)
            
        # also change the line break from \r\n to \n
        out = subprocess.check_output("fromdos " + f, shell = True)
    except IndexError:  # mac
        out = subprocess.check_output("file -b " + f, shell = True)
        curr_charset = out.split(' text')[0]

        if not any(curr_charset in charset for charset in ['UTF-8 Unicode', 'ASCII']):
            print curr_charset + '\t' + n
            commandstr = ("iconv -f " +  iconv_map[curr_charset] + " -t UTF-8 " + f + " > tmp.txt "
                          "&& mv -f tmp.txt " + f)
            out = subprocess.check_output(commandstr, shell = True)
        
        # also change the line break from \r\n to \n
        out = subprocess.check_output("sed -e 's/\r$//' " + f + " > tmp.txt "
                                      "&& mv -f tmp.txt " + f, shell = True)
# Out:
# iso-8859-1	huzzam--sarki--curcuna--mahzun_gonul--kemani_salih_efendi
# iso-8859-1	kurdilihicazkar--pesrev--muhammes----tanburi_cemil_bey
# iso-8859-1	beyati--sarki--aksak--karsidan_yar--dede_efendi
# iso-8859-1	hicazkar--sazsemaisi--aksaksemai----tanburi_cemil_bey
# iso-8859-1	hicaz--sarki--aksak--ben_gamli_hazan--melahat_pars
# iso-8859-1	saba--pesrev--duyek----tabi
# iso-8859-1	mahur--sarki--aksak--servinazi_seyret--rahmi_bey
# iso-8859-1	kurdilihicazkar--sarki--evfer--karsiyakada--lavtaci_hristo
# iso-8859-1	saba--sarki--duyek--gus_eyle--dede_efendi
# iso-8859-1	hicaz--beste--agircenber--dusmesin_miskin--zaharya
# iso-8859-1	rast--sarki--semai--yine_bir_gulnihal--dede_efendi
# iso-8859-1	hicaz--sarki--aksak--kis_geldi--sevki_bey
# iso-8859-1	muhayyer--turku--musemmen--elma_attim--tunceli
# iso-8859-1	segah--sarki--aksak--suyi_kagithanede--lavtaci_hristo
# iso-8859-1	buselik--nakis--yuruksemai--cefasi_asika--dellalzade
# iso-8859-1	saba--pesrev--devrikebir----tanburi_buyuk_osman_bey
# iso-8859-1	huseyni--turku--aksak--a_fadimem--
# iso-8859-1	huzzam--sarki--senginsemai--sen_sanki_baharin--musa_sureyya_bey
# iso-8859-1	huzzam--sarki--aksak--vefa_yoktur--tanburi_mustafa_cavus
# iso-8859-1	kurdilihicazkar--sarki--curcuna--hancer-i_ebrusu--asdik_aga
# iso-8859-1	kurdilihicazkar--sarki--duyek--arifem_ahkami--haci_arif_bey
# iso-8859-1	ussak--sarki--nimsofyan--gordum_seni--sadettin_kaynak
# iso-8859-1	nihavent--sarki--nimsofyan--biz_camlicanin--yesari_asim_arsoy
# iso-8859-1	beyati--sarki--aksak--benzemez_kimse--fehmi_tokay
# iso-8859-1	nihavent--sazeseri--nimsofyan--kanatlarim_olsaydi--serif_muhittin_targan
# iso-8859-1	huseyni--turku--curcuna--havada_bulut--
# iso-8859-1	beyati--sazsemaisi--aksaksemai----kanuni_omer_efendi
# iso-8859-1	mahur--sarki--aksak--bir_gonulde--mazhar_bey
# iso-8859-1	acemasiran--pesrev--devrikebir----neyzen_salih_dede
# iso-8859-1	huzzam--sarki--turkaksagi--sevdasi_henuz--yorgo_bacanos
# iso-8859-1	hicaz--sarki--nimsofyan--cok_yasa--muhlis_sabahaddin
# iso-8859-1	huzzam--sarki--aksak--zamani_var_ki--klarnet_ibrahim_efendi
# iso-8859-1	ussak--sarki--turkaksagi--hasret_dolu--serif_icli
# iso-8859-1	segah--sarki--yuruksemai--kapat_gozlerini--mustafa_seyran
# iso-8859-1	mahur--pesrev--duyek----gazi_giray_han
# iso-8859-1	saba--sarki--devrihindi--oyle_bir--aleko_bacanos
# iso-8859-1	nihavent--sarki--aksak--kiz_sen--faize_ergin
# iso-8859-1	hicaz--sarki--agiraksak--derdimi_ummana--serif_icli
# iso-8859-1	mahur--sarki--semai--asika_bagdat--munir_nurettin_selcuk
# iso-8859-1	nihavent--sarki--aksak--bakmiyor_cesm-i--haci_arif_bey
# iso-8859-1	hicaz--sarki--turkaksagi--yadeller_aldi--sadettin_kaynak
# iso-8859-1	mahur--sarki--evsat--sabah_olsun--ibrahim_aga
# iso-8859-1	huzzam--sarki--aksak--sevdim_yine--tanburi_mustafa_cavus
# iso-8859-1	ussak--sarki--aksak--bu_aksam_gun--tatyos_efendi
# iso-8859-1	rast--sarki--curcuna--nihansin_dideden--haci_faik_bey
# iso-8859-1	acemasiran--sarki--aksak--gordum_seni--irfan_dogrusoz
# iso-8859-1	nihavent--sarki--agiraksak--ahter-i_duskun--haci_arif_bey
# iso-8859-1	mahur--sarki--aksak--gonul_adli--dellalzade
# iso-8859-1	ussak--sarki--devrihindi--gozlerin_hayran--serif_icli
# iso-8859-1	buselik--sarki--turkaksagi--dun_gece_sende--sakir_aga
# iso-8859-1	huzzam--sarki--agiraksak--bekledim_yillarca--rakim_elkutlu
# iso-8859-1	hicaz--sarki--aksak--bilmiyorum--sevki_bey
# iso-8859-1	hicaz--sarki--curcuna--sislendi_hava--rifat_bey
# iso-8859-1	muhayyer--turku--sofyan--cayir_ince--
# iso-8859-1	ussak--sarki--aksak--bir_melek--haci_arif_bey
# iso-8859-1	huseyni--sarki--duyek--her_seherde--nihat_adlim
# iso-8859-1	buselik--sarki--aksak--dil_sana--tanburi_isak
# iso-8859-1	rast--sarki--duyek--omrumce_hep--irfan_ozbakir
# iso-8859-1	nihavent--sazsemaisi--senginsemai----hasib_dede
# iso-8859-1	muhayyer--sarki--aksak--iltimas_etmeye--haci_arif_bey
# iso-8859-1	saba--sarki--aksak--semt-i_dildare--suphi_ziya_ozbekkan
# iso-8859-1	huseyni--turku--aksak--yuce_dag--sadettin_kaynak
# iso-8859-1	hicaz--agirsemai--agirsenginsemai--guller_kizarir--ibrahim_aga
# iso-8859-1	huseyni--sarki--musemmen--hem_cemalin--zeki_duygulu
# iso-8859-1	kurdilihicazkar--sarki--curcuna--sana_ey--rahmi_bey
# iso-8859-1	rast--sarki--curcuna--mey-i_lalinle--tatyos_efendi
# iso-8859-1	kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi
# iso-8859-1	rast--sarki--semai--sevmek_seni--neveser_kokdes
# iso-8859-1	kurdilihicazkar--sarki--sofyan--beni_kor_kuyularda--munir_nurettin_selcuk
# iso-8859-1	mahur--sarki--aksak--iki_gozum--kemal_emin_bara
# iso-8859-1	muhayyer--turku--duyek--iste_seni--sadettin_kaynak
# iso-8859-1	buselik--sarki--curcuna--aman_cana--fehmi_tokay
# iso-8859-1	nihavent--sarki--turkaksagi--korfezdeki_dalgin--osman_nihat_akin
# iso-8859-1	hicazkar--sarki--sofyan--ben_sozune--numan_aga
# iso-8859-1	ussak--sarki--senginsemai--askin_ile--kadikoylu_ali_bey
# iso-8859-1	huzzam--sarki--agiraksak--sabrimi_gamzelerin--bimen_sen
# iso-8859-1	segah--sarki--curcuna--hasta_kalbimde--kaptanzade_ali_riza_bey
# iso-8859-1	segah--sarki--agiraksak--bensiz_ey--bimen_sen
# iso-8859-1	hicaz--sarki--yuruksemai--gittin_de_biraktin--munir_nurettin_selcuk
# iso-8859-1	ussak--sarki--curcuna--esiri_zulfunum--sevki_bey
# iso-8859-1	hicazkar--sarki--devrihindi--lezzet_almis--ahmet_mithat_bey
# iso-8859-1	rast--sarki--duyek--bana_nasil--alaeddin_yavasca
# iso-8859-1	mahur--sarki--duyek--petek_petek--erol_sayan
# iso-8859-1	nihavent--beste--lenkfahte--zulfun_gorenlerin--ali_rifat_bey
# iso-8859-1	huzzam--sarki--senginsemai--acmam_acamam--nasibin_mehmet_yuru
# iso-8859-1	saba--turku--sofyan--mendilimin_yesili--
# iso-8859-1	hicaz--yuruksemai--yuruksemai--yine_nese-i--dede_efendi
# iso-8859-1	huzzam--pesrev--devrikebir----tanburi_buyuk_osman_bey
# iso-8859-1	kurdilihicazkar--sarki--curcuna--gurub_etti--haci_arif_bey
# iso-8859-1	saba--sarki--aksak--mey_icerken--sevki_bey
# iso-8859-1	mahur--pesrev--hafif----rauf_yekta
# iso-8859-1	huzzam--sarki--aksak--gonul_verdim--iii_selim
# iso-8859-1	segah--sarki--duyek--ayrilik_yaman--sadettin_kaynak
# iso-8859-1	mahur--sarki--duyek--ayrilik_ruzgari--kamuran_yarkin
# iso-8859-1	nihavent--sarki--yuruksemai--suzup_suzup--rahmi_bey
# iso-8859-1	huseyni--sazsemaisi--aksaksemai----tatyos_efendi
# iso-8859-1	kurdilihicazkar--sarki--aksak--gidelim_goksuya--lavtaci_hristo
# iso-8859-1	huseyni--turku--duyek--koskum_var--
# iso-8859-1	nihavent--sarki--sofyan--gonlumle_oturdum--sekip_mahmut_bey
# iso-8859-1	huseyni--pesrev--muhammes----lavtaci_andon
# iso-8859-1	saba--turku--sofyan--bir_dalda--istanbul
# iso-8859-1	beyati--sarki--devrihindi--nar-i_firkat--mahmut_celalettin_pasa
# iso-8859-1	rast--sarki--duyek--hicran_olacaksa--ferit_sidal
# iso-8859-1	ussak--sarki--agiraksak--kaldi_atesler--haci_karabet_efendi
# iso-8859-1	segah--sarki--curcuna--olmaz_ilac--haci_arif_bey
# iso-8859-1	kurdilihicazkar--sarki--senginsemai--her_tel--kaptanzade_aliriza_bey
# iso-8859-1	kurdilihicazkar--sarki--aksak--muntazir_tesrifine--haci_arif_bey
# iso-8859-1	buselik--sarki--semai--dil_bestenim--vecdi_seyhun
# iso-8859-1	hicaz--sarki--duyek--artik_bu--alaeddin_yavasca
# iso-8859-1	hicaz--sarki--semai--ey_mehlika--ismail_hakki_bey
# iso-8859-1	rast--sazsemaisi--aksaksemai----kantemiroglu
# iso-8859-1	rast--sarki--curcuna--hatirimdan_cikmaz--haci_arif_bey
# iso-8859-1	hicaz--sarki--turkaksagi--saydeyledi_bu--haci_arif_bey
# iso-8859-1	kurdilihicazkar--sarki--agiraksak--koparan_sinemi--bimen_sen
# iso-8859-1	segah--sarki--aksak--seni_her_dem--misirli_ibrahim
# iso-8859-1	huzzam--sarki--duyek--sacin_yuzume--teoman_alpay
# iso-8859-1	kurdilihicazkar--sarki--musemmen--iftirakindir_sebep--haci_arif_bey
# iso-8859-1	segah--sarki--nimsofyan--gel_gitme--kaptanzade
# iso-8859-1	huzzam--sarki--turkaksagi--baglandi_gonul--selanikli_ahmet_efendi
# iso-8859-1	acemasiran--zeybek--agiraksak--su_izmirin--tahsin_karakus
# iso-8859-1	huzzam--sarki--curcuna--aksam_donusu--udi_marko
# iso-8859-1	huseyni--sarki--agiraksak--firkat-i_canan--civan_aga
# iso-8859-1	hicazkar--sarki--duyek--cozmek_elinde--sadettin_kaynak
# iso-8859-1	hicazkar--sarki--aksak--bekledim_fecre--rakim_elkutlu
# iso-8859-1	nihavent--pesrev--devrikebir----tanburi_buyuk_osman_bey
# iso-8859-1	mahur--tavsanca--aksak--nazar_etti--tanburi_mustafa_cavus
# iso-8859-1	mahur--sarki--curcuna--zahiri_hale--haci_arif_bey
# iso-8859-1	hicaz--sarki--sofyan--enginde_yavas--sadettin_kaynak
# iso-8859-1	huseyni--sarki--aksak--sevdigim_cemalin--mahmut_celalettin_pasa
# iso-8859-1	muhayyer--sarki--yuruksemai--sevdicegim_asikini--dede_efendi
# iso-8859-1	mahur--sarki--aksak--ver_saki--refik_fersan
# iso-8859-1	ussak--sarki--duyek--aksam_oldu--semahat_ozdenses
# iso-8859-1	mahur--sarki--duyek--saba_tarf-i--hafiz_husnu_efendi
# iso-8859-1	hicaz--sarki--curcuna--aksam_erdi--rahmi_bey
# iso-8859-1	nihavent--sarki--aksak--yok_baska--munir_nurettin_selcuk
# iso-8859-1	acemasiran--sazsemaisi--aksaksemai----udi_ibrahim_efendi
# iso-8859-1	hicaz--mandra--devrituran--hicaz_mandra--lavtaci_andon
# iso-8859-1	huseyni--sarki--musemmen--gecti_sevdalarla--sukru_tunar
# iso-8859-1	segah--sarki--semai--gurbet_icimde--teoman_alpay
# iso-8859-1	hicaz--sarki--semai--sana_dun--munir_nurettin_selcuk
# iso-8859-1	segah--sarki--aksak--gel_ey--tanburi_cemil_bey
# iso-8859-1	hicaz--sarki--aksak--su_karsiki_dagda--dede_efendi
# iso-8859-1	huzzam--sarki--turkaksagi--meftun_olali--haci_arif_bey
# iso-8859-1	mahur--sarki--sofyan--ne_dogan--munir_nurettin_selcuk
# iso-8859-1	segah--tekbir--durakevferi--allah_u_ekber--itri
# iso-8859-1	hicaz--sarki--aksak--beni_sev--udi_ibrahim_efendi
# iso-8859-1	hicazkar--sarki--aksak--severim_her--nefise_hanim
# iso-8859-1	acemasiran--sarki--yuruksemai--gel_ey_denizin--aleko_bacanos
# iso-8859-1	hicaz--sarki--aksak--dil_yaresini--sevki_bey
# iso-8859-1	muhayyer--sarki--aksak--bir_gonulde--ahmet_rasim_bey
# iso-8859-1	rast--sarki--aksak--bin_can_ile--tanburi_buyuk_osman_bey
# iso-8859-1	acemasiran--sarki--sofyan--bakma_sakin--sakir_aga
# iso-8859-1	rast--sarki--senginsemai--bir_gonlume--tatyos_efendi
# iso-8859-1	nihavent--fantezi--nimsofyan--benim_gonlum--kaptanzade
# iso-8859-1	huzzam--sazsemaisi--aksaksemai----udi_nevres_bey
# iso-8859-1	mahur--sarki--aksak--su_guzele--semseddin_ziya_bey
# iso-8859-1	rast--sarki--semai--perisan_saclarin--yesari_asim_arsoy
# iso-8859-1	kurdilihicazkar--sirto--nimsofyan----kemani_sebuh
# iso-8859-1	segah--sarki--devrihindi--dil_harab-i--tanburi_ali_efendi
# iso-8859-1	acemasiran--sarki--agiraksak--bir_haber--bimen_sen
# iso-8859-1	mahur--sarki--aksak--sana_layik_mi--dede_efendi
# iso-8859-1	hicaz--turku--sofyan--ela_gozlerine--sadettin_kaynak
# iso-8859-1	ussak--sarki--curcuna--cana_rakibi--giriftzen_asim_bey
# iso-8859-1	huzzam--sarki--semai--omrumuzun_son_saati--avni_anil
# iso-8859-1	huseyni--sarki--curcuna--bak_su--danbeni_riza_bey
# iso-8859-1	huseyni--sarki--agiraksak--farig_olmam--yesari_asim_arsoy
# iso-8859-1	huzzam--sarki--senginsemai--hal-i_dil-i--haci_arif_bey
# iso-8859-1	hicazkar--beste--yuruksemai--bulbul_gibi--zekai_dede
# iso-8859-1	rast--turku--semai--gul_agaci--necip_mirkelamoglu
# iso-8859-1	saba--sarki--duyek--seni_herkesten--yesari_asim_arsoy
# iso-8859-1	rast--sarki--duyek--bir_gonul--ferit_sidal
# iso-8859-1	huseyni--turku--sofyan--keklik_daglarda--
# iso-8859-1	kurdilihicazkar--sarki--aydin--gozlerin_mavi--refik_fersan
# iso-8859-1	nihavent--sarki--duyek--unutturamaz_seni--ekrem_guyer
# iso-8859-1	muhayyer--sarki--aksak--humari_yok--haci_arif_bey
# iso-8859-1	ussak--sarki--duyek--her_mevsim--semahat_ozdenses
# iso-8859-1	huzzam--sarki--curcuna--omrum_seni--yesari_asim_arsoy
# iso-8859-1	segah--salatiummiye--aksaksemaievferi--allahumme_salli--itri
# iso-8859-1	huseyni--turku--aksak--yanik_omer--sadettin_kaynak
# iso-8859-1	rast--sarki--duyek--uftadenim_ey--dede_efendi
# iso-8859-1	mahur--sarki--duyek--ben_guzele--sadettin_kaynak
# iso-8859-1	huseyni--sarki--turkaksagi--hicran_oku--sevki_bey
# iso-8859-1	segah--ilahi--sofyan--sordum_sari--
# iso-8859-1	huzzam--sarki--curcuna--guzel_gun_gormedi--haci_arif_bey
# iso-8859-1	huseyni--beste--duyek--muheyya_oldu--rakim_elkutlu
# iso-8859-1	rast--yuruksemai--yuruksemai--gelse_o_suh--hafiz_post
# iso-8859-1	nihavent--sarki--curcuna--kimseye_etmem--kemani_sarkis_efendi
# iso-8859-1	nihavent--sarki--curcuna--guzel_bir--osman_nihat_akin
# iso-8859-1	ussak--pesrev--cenber----zurnazen_ibrahim_aga
# iso-8859-1	hicazkar--sarki--curcuna--senelerce--sabri_suha_ansen
# iso-8859-1	huzzam--sarki--aksak--gonlum_seher--sadettin_kaynak
# iso-8859-1	huseyni--agirsemai--aksaksemai--talatin_devri--zaharya
# iso-8859-1	ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede
# iso-8859-1	nihavent--sarki--aksak--gel_guzelim--faiz_kapanci
# iso-8859-1	muhayyer--sarki--aksaksemai--gun_kavustu--udi_nevres_bey
# iso-8859-1	hicaz--sarki--turkaksagi--ey_cerhi_sitemger--medeni_aziz_efendi
# iso-8859-1	mahur--yuruksemai--yuruksemai--yine_zevrak-i--dede_efendi
# iso-8859-1	rast--sarki--yuruksemai--sevdim_yine--basmaci_abdi_efendi
# iso-8859-1	huseyni--sarki--devrihindi--gormek_ister--tanburi_cemil_bey
# iso-8859-1	hicaz--sarki--senginsemai--derdimi_arz--enderuni_ali_bey
# iso-8859-1	segah--sarki--murekkepnimsofyan--dustu_enginlere--refik_fersan
# iso-8859-1	saba--ilahi--duyek--git_ey--munir_nurettin_selcuk
# iso-8859-1	muhayyer--sarki--sofyan--nicin_mahzun--haci_arif_bey
# iso-8859-1	segah--yuruksemai--yuruksemai--etti_o_guzel--ebubekir_aga
# iso-8859-1	mahur--mars--nimhafif--vur_pence-i--munir_nurettin_selcuk
# iso-8859-1	hicaz--sarki--aksak--sazlar_calinir--yesari_asim_arsoy
# iso-8859-1	huseyni--sarki--aksak--varalim_kuy-i--munir_nurettin_selcuk
# iso-8859-1	ussak--sarki--duyek--menekse_gozler--yesari_asim_arsoy
# iso-8859-1	hicaz--sarki--turkaksagi--solsan_da_sararsan--misirli_ibrahim
# iso-8859-1	huzzam--sarki--aksak--adanin_yesil_camlari--sukru_tunar
# iso-8859-1	hicaz--sarki--agiraksak--bir_nigah_et--sekerci_cemil_bey
# iso-8859-1	segah--sarki--duyek--donulmez_aksamin--munir_nurettin_selcuk
# iso-8859-1	hicaz--turku--aksak--karanfil_oylum_oylum--
# iso-8859-1	kurdilihicazkar--sarki--sofyan--baga_girdim_kamisa--_rustu_eric_
# iso-8859-1	rast--sarki--yuruksemai--yuzundur_cihani--dede_efendi
# iso-8859-1	beyati--sarki--aksak--ne_semtden--kemani_riza_efendi
# iso-8859-1	rast--sarki--sofyan--karli_dagi--rifat_bey
# iso-8859-1	rast--sarki--duyek--sensiz_kalan--irfan_ozbakir
# iso-8859-1	huseyni--sarki--curcuna--nedir_bu_haletin--sevki_bey
# iso-8859-1	hicaz--sarki--duyek--yalan_degil--yusuf_nalkesen
# iso-8859-1	hicaz--sarki--aksak--hastayim_yasiyorum--hirant_kenkiloglu
# iso-8859-1	saba--sarki--aksak--bir_nigah--zeki_arif_ataergin
# iso-8859-1	hicaz--sarki--sofyan--ada_sahillerinde--
# iso-8859-1	segah--sarki--murekkepnimsofyan--olursem_yaziktir--hayri_yenigun
# iso-8859-1	rast--pesrev--sakil----benli_hasan_aga
# iso-8859-1	acemasiran--sarki--agiraksak--goncasindan_gulsenin--emin_ongan
# iso-8859-1	segah--sazsemaisi--aksaksemai----nayi_osman_dede
# iso-8859-1	rast--sarki--duyek--belki_bir_sabah--sekip_ayhan_ozisik
# iso-8859-1	muhayyer--sarki--curcuna--batan_gun--sadettin_kaynak
# iso-8859-1	nihavent--sarki--duyek--askimin_ilk--arif_sami_toker
# iso-8859-1	huzzam--sarki--aksak--sevdigin_dunyalar--munir_nurettin_selcuk
# iso-8859-1	rast--kar-i_nev--agirduyek--gozumde_daim--dede_efendi
# iso-8859-1	huzzam--sarki--curcuna--kusade_taliim--sevki_bey
# iso-8859-1	kurdilihicazkar--sarki--aksak--nicin_terkeyleyip--haci_arif_bey
# iso-8859-1	beyati--sarki--ciftesofyan--cikalim_sayd_u--tanburi_mustafa_cavus
# iso-8859-1	rast--sarki--turkaksagi--esti_nesim-i_nevbahar--haci_arif_bey
# iso-8859-1	hicazkar--pesrev--devrikebir----osman_bey
# iso-8859-1	nihavent--yuruksemai--yuruksemai--ayrildi_gonul--zeki_duygulu
# iso-8859-1	hicaz--sarki--aksak--gulsen-i_husnune--rifat_bey
# iso-8859-1	rast--sarki--curcuna--anlatayim_halimi--tanburi_ali_efendi
# iso-8859-1	huseyni--sarki--sofyan--tez_gecse_de--selahaddin_inal
# iso-8859-1	huzzam--sarki--aksak--ettigin_cevri--cinucen_tanrikorur
# iso-8859-1	acemasiran--sarki--aksak--oldu_gonul--dede_efendi
# iso-8859-1	hicaz--sarki--curcuna--anlatilmaz_bin--erdogan_yildizel
# iso-8859-1	nihavent--sarki--sofyan--ne_dert--sadettin_kaynak
# iso-8859-1	huseyni--sarki--aksak--bir_dilberdir--tanburi_mustafa_cavus
# iso-8859-1	huzzam--turku--sofyan--aksam_oldu--rumeli
# iso-8859-1	huzzam--sarki--aksak--gozum_hasretle--tatyos_efendi
# iso-8859-1	huzzam--sarki--duyek--a_canim--tanburi_mustafa_cavus
# iso-8859-1	ussak--turku--sofyan--uzun_ince--asik_veysel
# iso-8859-1	huzzam--sarki--sofyan--solgun_durma--munir_nurettin_selcuk
# iso-8859-1	huseyni--sarki--curcuna--cektim_elimi--tatyos_efendi
# iso-8859-1	hicazkar--sarki--devrihindi--gonlumu_ducar--sevki_bey
# iso-8859-1	huzzam--turku--nimsofyan--kopruler_yaptirdim--_mustafa_sagyasar_
# iso-8859-1	huzzam--sarki--agiraksak--ben_esir-i--udi_arsak
# iso-8859-1	rast--sarki--musemmen--vuslatindan_gayri--haci_arif_bey
# iso-8859-1	rast--sarki--senginsemai--dil_bir--dede_efendi
# iso-8859-1	hicaz--kalenderi--aksak--ebrulerinin_zahmi--
# iso-8859-1	segah--sarki--agiraksak--hatir-i_nasadi--tanburi_cemil_bey
# iso-8859-1	segah--turku--curcuna--incecikten_bir--sadettin_kaynak
# iso-8859-1	hicazkar--sarki--curcuna--mani_oluyor--tatyos_efendi
# iso-8859-1	segah--sarki--aksak--benim_sen--ahmet_rasim
# iso-8859-1	segah--turku--nimsofyan--acilir_gonca_gul--erol_sayan
# iso-8859-1	hicazkar--pesrev--muhammes----tanburi_cemil_bey
# iso-8859-1	segah--ilahi--yuruksemai--sol_cennetin--
# iso-8859-1	saba--turku--aksak--daracik_sokaklari--istanbul
# iso-8859-1	ussak--sazsemaisi--aksaksemai----dede_salih_efendi
# iso-8859-1	hicaz--sarki--aksak--bir_bahar--selahattin_pinar
# iso-8859-1	segah--pesrev--devrikebir----yusuf_pasa
# iso-8859-1	huzzam--sarki--aksak--ey_gul-i--dede_efendi
# iso-8859-1	rast--sarki--aksak--calima_bak--lavtaci_hristo
# iso-8859-1	kurdilihicazkar--sarki--yuruksemai--sen_gozlerine--misirli_ibrahim
# iso-8859-1	saba--sarki--duyek--gule_sorma--erol_sayan
# iso-8859-1	hicazkar--sarki--duyek--yuzun_gullerden--sadettin_kaynak
# iso-8859-1	segah--turku--aksak--izmirin_kavaklari--
# iso-8859-1	nihavent--sarki--yuruksemai--semalardan_gunes--misirli_udi_ibrahim
# iso-8859-1	nihavent--sarki--aksak--koklasam_saclarini--artaki_candan
# iso-8859-1	hicazkar--sarki--curcuna--mestim_bu_gece--lavtaci_ovrik
# iso-8859-1	hicaz--sarki--yuruksemai--ey_but-i--dede_efendi
# iso-8859-1	huseyni--sarki--yuruksemai--senden_bilirim--tanburi_ali_efendi
# iso-8859-1	rast--sarki--senginsemai--bilmem_ki--selanikli_ahmed_efendi
# iso-8859-1	saba--sarki--senginsemai--neydin_guzelim--serif_icli
# iso-8859-1	ussak--sarki--agiraksak--reng-i_ruhsarina--sevki_bey
# iso-8859-1	rast--kar-i_natik--yuruksemai_6_4--rast_getirub--dede_efendi
# iso-8859-1	saba--sarki--devrihindi--nigah-i_mestine--haci_arif_bey
# iso-8859-1	huseyni--sarki--aksak--ezelden_asinanim--serif_icli
# iso-8859-1	nihavent--sarki--duyek--bir_ihtimal--osman_nihat_akin
# iso-8859-1	hicazkar--sarki--sofyan--bir_halet--haci_arif_bey
# iso-8859-1	kurdilihicazkar--sarki--agiraksak--bu_gonul--sari_onnik
# iso-8859-1	rast--sarki--curcuna--nedendir_bu--sevki_bey
# iso-8859-1	hicaz--sarki--agir_aksaksemai--hasret_odu--tanburi_ali_efendi
# iso-8859-1	rast--sarki--duyek--gorsem_seni--dede_efendi
# iso-8859-1	ussak--sarki--sofyan--gamzedeyim_deva--tatyos_efendi
# iso-8859-1	ussak--sarki--turkaksagi--yalniz_birakip--udi_ibrahim_efendi
# iso-8859-1	segah--yuruksemai--yuruksemai--tuti_i_mucize--itri
# iso-8859-1	saba--sarki--aksak--bir_esmere--tanburi_mustafa_cavus
# iso-8859-1	nihavent--sarki--senginsemai--bir_asik-i--afet_misirliyan
# iso-8859-1	hicaz--sarki--evfer--mah_yuzune--dede_efendi
# iso-8859-1	hicaz--kocekce--aksak--baharin_zamani--dede_efendi
# iso-8859-1	ussak--sarki--aksak--gitti_de--dede_efendi
# iso-8859-1	ussak--sarki--agiraksak--kimseler_gelmez--sevki_bey
# iso-8859-1	hicaz--sarki--agirevfer--bak_ne_hale--haci_arif_bey
# iso-8859-1	nihavent--sarki--semai--kacsam_birakip--mehves_hanim
# iso-8859-1	rast--nakis_beste--duyek--amed_nesim-i--abdulkadir_meragi
# iso-8859-1	rast--turku--sofyan--adananin_yollari--
# iso-8859-1	rast--sarki--semai--gecsin_gunler--erol_sayan
# iso-8859-1	huzzam--yuruksemai--yuruksemai--reh-i_askinda--dede_efendi
# iso-8859-1	rast--sarki--yuruksemai--unutulmus_birer--gultekin_ceki
# iso-8859-1	huseyni--oyunhavasi--nimsofyan--cecen_kizi--tanburi_cemil_bey
# iso-8859-1	huseyni--sarki--curcuna--edali_bir--ali_rifat_cagatay
# iso-8859-1	hicaz--sarki--nimsofyan--sari_kurdelem--fahri_kayahan
# iso-8859-1	huseyni--turku--curcuna--sari_gelin--erzurum
# iso-8859-1	ussak--sarki--aksak--zeybeklerle_gezer--sevki_bey
# iso-8859-1	hicaz--pesrev--fahte----neyzen_salim_bey
# iso-8859-1	segah--sarki--turkaksagi--sevda_yaratan--yesari_asim_arsoy
# iso-8859-1	rast--sarki--curcuna--asik_oldur--haci_arif_bey
# iso-8859-1	nihavent--sarki--turkaksagi--ben_buy-i--haci_arif_bey
# iso-8859-1	hicazkar--sarki--agiraksak--kirsa_bin_tel--bimen_sen
# iso-8859-1	hicaz--beste--agirduyek--ey_cesm-i--dede_efendi
# iso-8859-1	huseyni--turku--curcuna--sinemde_bir--
# iso-8859-1	ussak--sarki--aksak--gulzara_nazar--sevki_bey
# iso-8859-1	kurdilihicazkar--sazsemaisi--aksaksemai----tatyos_efendi
# iso-8859-1	segah--sarki--duyek--leyla_bir--sadettin_kaynak
# iso-8859-1	huseyni--turku--raksaksagi--menekse_kokulu--
# iso-8859-1	hicazkar--sazsemaisi--aksaksemai----tanburi_cemil_bey
# iso-8859-1	hicaz--sarki--aksak--ben_gamli_hazan--melahat_pars
# iso-8859-1	saba--sarki--duyek--gus_eyle--dede_efendi
# iso-8859-1	hicaz--beste--agircenber--dusmesin_miskin--zaharya
# iso-8859-1	rast--sarki--semai--yine_bir_gulnihal--dede_efendi
# iso-8859-1	hicaz--sarki--aksak--kis_geldi--sevki_bey
# iso-8859-1	segah--sarki--aksak--suyi_kagithanede--lavtaci_hristo
# iso-8859-1	saba--pesrev--devrikebir----tanburi_buyuk_osman_bey
# iso-8859-1	huseyni--turku--aksak--a_fadimem--
# iso-8859-1	huzzam--sarki--aksak--vefa_yoktur--tanburi_mustafa_cavus
# iso-8859-1	kurdilihicazkar--sarki--curcuna--hancer-i_ebrusu--asdik_aga
# iso-8859-1	kurdilihicazkar--sarki--duyek--arifem_ahkami--haci_arif_bey
# iso-8859-1	ussak--sarki--nimsofyan--gordum_seni--sadettin_kaynak
# iso-8859-1	nihavent--sarki--nimsofyan--biz_camlicanin--yesari_asim_arsoy
# iso-8859-1	nihavent--sazeseri--nimsofyan--kanatlarim_olsaydi--serif_muhittin_targan
# iso-8859-1	huseyni--turku--curcuna--havada_bulut--
# iso-8859-1	huzzam--sarki--turkaksagi--sevdasi_henuz--yorgo_bacanos
# iso-8859-1	ussak--sarki--turkaksagi--hasret_dolu--serif_icli
# iso-8859-1	segah--sarki--yuruksemai--kapat_gozlerini--mustafa_seyran
# iso-8859-1	saba--sarki--devrihindi--oyle_bir--aleko_bacanos
# iso-8859-1	hicaz--sarki--agiraksak--derdimi_ummana--serif_icli
# iso-8859-1	nihavent--sarki--aksak--bakmiyor_cesm-i--haci_arif_bey
# iso-8859-1	hicaz--sarki--turkaksagi--yadeller_aldi--sadettin_kaynak
# iso-8859-1	huzzam--sarki--aksak--sevdim_yine--tanburi_mustafa_cavus
# iso-8859-1	ussak--sarki--aksak--bu_aksam_gun--tatyos_efendi
# iso-8859-1	rast--sarki--curcuna--nihansin_dideden--haci_faik_bey
# iso-8859-1	nihavent--sarki--agiraksak--ahter-i_duskun--haci_arif_bey
# iso-8859-1	ussak--sarki--devrihindi--gozlerin_hayran--serif_icli
# iso-8859-1	hicaz--sarki--aksak--bilmiyorum--sevki_bey
# iso-8859-1	muhayyer--turku--sofyan--cayir_ince--
# iso-8859-1	ussak--sarki--aksak--bir_melek--haci_arif_bey
# iso-8859-1	rast--sarki--duyek--omrumce_hep--irfan_ozbakir
# iso-8859-1	nihavent--sazsemaisi--senginsemai----hasib_dede
# iso-8859-1	saba--sarki--aksak--semt-i_dildare--suphi_ziya_ozbekkan
# iso-8859-1	huseyni--turku--aksak--yuce_dag--sadettin_kaynak
# iso-8859-1	huseyni--sarki--musemmen--hem_cemalin--zeki_duygulu
# iso-8859-1	kurdilihicazkar--sarki--sofyan--beni_kor_kuyularda--munir_nurettin_selcuk
# iso-8859-1	ussak--sarki--senginsemai--askin_ile--kadikoylu_ali_bey
# iso-8859-1	huzzam--sarki--agiraksak--sabrimi_gamzelerin--bimen_sen
# iso-8859-1	segah--sarki--agiraksak--bensiz_ey--bimen_sen
# iso-8859-1	hicaz--sarki--yuruksemai--gittin_de_biraktin--munir_nurettin_selcuk
# iso-8859-1	ussak--sarki--curcuna--esiri_zulfunum--sevki_bey
# iso-8859-1	rast--sarki--duyek--bana_nasil--alaeddin_yavasca
# iso-8859-1	saba--turku--sofyan--mendilimin_yesili--
# iso-8859-1	hicaz--yuruksemai--yuruksemai--yine_nese-i--dede_efendi
# iso-8859-1	huzzam--sarki--aksak--gonul_verdim--iii_selim
# iso-8859-1	segah--sarki--duyek--ayrilik_yaman--sadettin_kaynak
# iso-8859-1	nihavent--sarki--yuruksemai--suzup_suzup--rahmi_bey
# iso-8859-1	huseyni--sazsemaisi--aksaksemai----tatyos_efendi
# iso-8859-1	huseyni--turku--duyek--koskum_var--
# iso-8859-1	huseyni--pesrev--muhammes----lavtaci_andon
# iso-8859-1	saba--turku--sofyan--bir_dalda--istanbul
# iso-8859-1	rast--sarki--duyek--hicran_olacaksa--ferit_sidal
# iso-8859-1	ussak--sarki--agiraksak--kaldi_atesler--haci_karabet_efendi
# iso-8859-1	segah--sarki--curcuna--olmaz_ilac--haci_arif_bey
# iso-8859-1	rast--sarki--curcuna--hatirimdan_cikmaz--haci_arif_bey
# iso-8859-1	hicaz--sarki--turkaksagi--saydeyledi_bu--haci_arif_bey
# iso-8859-1	segah--sarki--aksak--seni_her_dem--misirli_ibrahim
# iso-8859-1	huzzam--sarki--duyek--sacin_yuzume--teoman_alpay
# iso-8859-1	kurdilihicazkar--sarki--musemmen--iftirakindir_sebep--haci_arif_bey
# iso-8859-1	huzzam--sarki--curcuna--aksam_donusu--udi_marko
# iso-8859-1	hicazkar--sarki--duyek--cozmek_elinde--sadettin_kaynak
# iso-8859-1	nihavent--pesrev--devrikebir----tanburi_buyuk_osman_bey
# iso-8859-1	hicaz--sarki--sofyan--enginde_yavas--sadettin_kaynak
# iso-8859-1	ussak--sarki--duyek--aksam_oldu--semahat_ozdenses
# iso-8859-1	hicaz--mandra--devrituran--hicaz_mandra--lavtaci_andon
# iso-8859-1	huseyni--sarki--musemmen--gecti_sevdalarla--sukru_tunar
# iso-8859-1	segah--sarki--semai--gurbet_icimde--teoman_alpay
# iso-8859-1	segah--sarki--aksak--gel_ey--tanburi_cemil_bey
# iso-8859-1	hicaz--sarki--aksak--su_karsiki_dagda--dede_efendi
# iso-8859-1	segah--tekbir--durakevferi--allah_u_ekber--itri
# iso-8859-1	hicaz--sarki--aksak--beni_sev--udi_ibrahim_efendi
# iso-8859-1	hicazkar--sarki--aksak--severim_her--nefise_hanim
# iso-8859-1	hicaz--sarki--aksak--dil_yaresini--sevki_bey
# iso-8859-1	rast--sarki--senginsemai--bir_gonlume--tatyos_efendi
# iso-8859-1	huzzam--sazsemaisi--aksaksemai----udi_nevres_bey
# iso-8859-1	rast--sarki--semai--perisan_saclarin--yesari_asim_arsoy
# iso-8859-1	kurdilihicazkar--sirto--nimsofyan----kemani_sebuh
# iso-8859-1	hicaz--turku--sofyan--ela_gozlerine--sadettin_kaynak
# iso-8859-1	huzzam--sarki--semai--omrumuzun_son_saati--avni_anil
# iso-8859-1	huseyni--sarki--agiraksak--farig_olmam--yesari_asim_arsoy
# iso-8859-1	rast--turku--semai--gul_agaci--necip_mirkelamoglu
# iso-8859-1	saba--sarki--duyek--seni_herkesten--yesari_asim_arsoy
# iso-8859-1	huseyni--turku--sofyan--keklik_daglarda--
# iso-8859-1	ussak--sarki--duyek--her_mevsim--semahat_ozdenses
# iso-8859-1	huzzam--sarki--curcuna--omrum_seni--yesari_asim_arsoy
# iso-8859-1	segah--salatiummiye--aksaksemaievferi--allahumme_salli--itri
# iso-8859-1	huseyni--turku--aksak--yanik_omer--sadettin_kaynak
# iso-8859-1	rast--sarki--duyek--uftadenim_ey--dede_efendi
# iso-8859-1	huseyni--sarki--turkaksagi--hicran_oku--sevki_bey
# iso-8859-1	huzzam--sarki--curcuna--guzel_gun_gormedi--haci_arif_bey
# iso-8859-1	nihavent--sarki--curcuna--kimseye_etmem--kemani_sarkis_efendi
# iso-8859-1	huseyni--agirsemai--aksaksemai--talatin_devri--zaharya
# iso-8859-1	ussak--sazsemaisi--aksaksemai----neyzen_aziz_dede
# iso-8859-1	nihavent--sarki--aksak--gel_guzelim--faiz_kapanci
# iso-8859-1	huseyni--sarki--devrihindi--gormek_ister--tanburi_cemil_bey
# iso-8859-1	hicaz--sarki--senginsemai--derdimi_arz--enderuni_ali_bey
# iso-8859-1	segah--yuruksemai--yuruksemai--etti_o_guzel--ebubekir_aga
# iso-8859-1	hicaz--sarki--aksak--sazlar_calinir--yesari_asim_arsoy
# iso-8859-1	ussak--sarki--duyek--menekse_gozler--yesari_asim_arsoy
# iso-8859-1	hicaz--sarki--agiraksak--bir_nigah_et--sekerci_cemil_bey
# iso-8859-1	segah--sarki--duyek--donulmez_aksamin--munir_nurettin_selcuk
# iso-8859-1	hicaz--turku--aksak--karanfil_oylum_oylum--
# iso-8859-1	kurdilihicazkar--sarki--sofyan--baga_girdim_kamisa--_rustu_eric_
# iso-8859-1	rast--sarki--yuruksemai--yuzundur_cihani--dede_efendi
# iso-8859-1	rast--sarki--duyek--sensiz_kalan--irfan_ozbakir
# iso-8859-1	hicaz--sarki--aksak--hastayim_yasiyorum--hirant_kenkiloglu
# iso-8859-1	saba--sarki--aksak--bir_nigah--zeki_arif_ataergin
# iso-8859-1	hicaz--sarki--sofyan--ada_sahillerinde--
# iso-8859-1	segah--sarki--murekkepnimsofyan--olursem_yaziktir--hayri_yenigun
# iso-8859-1	rast--pesrev--sakil----benli_hasan_aga
# iso-8859-1	rast--sarki--duyek--belki_bir_sabah--sekip_ayhan_ozisik
# iso-8859-1	huzzam--sarki--aksak--sevdigin_dunyalar--munir_nurettin_selcuk
# iso-8859-1	rast--kar-i_nev--agirduyek--gozumde_daim--dede_efendi
# iso-8859-1	huzzam--sarki--curcuna--kusade_taliim--sevki_bey
# iso-8859-1	rast--sarki--turkaksagi--esti_nesim-i_nevbahar--haci_arif_bey
# iso-8859-1	hicazkar--pesrev--devrikebir----osman_bey
# iso-8859-1	nihavent--yuruksemai--yuruksemai--ayrildi_gonul--zeki_duygulu
# iso-8859-1	huseyni--sarki--sofyan--tez_gecse_de--selahaddin_inal
# iso-8859-1	nihavent--sarki--sofyan--ne_dert--sadettin_kaynak
# iso-8859-1	huseyni--sarki--aksak--bir_dilberdir--tanburi_mustafa_cavus
# iso-8859-1	huzzam--turku--sofyan--aksam_oldu--rumeli
# iso-8859-1	huzzam--sarki--aksak--gozum_hasretle--tatyos_efendi
# iso-8859-1	hicaz--sarki--agiraksak--seni_sevda_cicegim--misirli_ibrahim
# iso-8859-1	hicaz--sazsemaisi--aksaksemai----refik_talat_bey
# iso-8859-1	nihavent--sarki--semai--hatirla_ey_peri--muhlis_sabahadin
# iso-8859-1	nihavent--sarki--semai--erisdi_nevbahar--arif_sami_toker
# iso-8859-1	buselik--sarki--sofyan--aldin_aklim--rifat_bey
# iso-8859-1	huseyni--sarki--curcuna--cektim_elimi--tatyos_efendi
# iso-8859-1	hicazkar--sarki--devrihindi--gonlumu_ducar--sevki_bey
# iso-8859-1	nihavent--sarki--yuruksemai--tez_gecse_de--sadettin_kaynak
# iso-8859-1	hicaz--sarki--semai--sirma_sacli--misirli_ibrahim_efendi
# iso-8859-1	rast--sarki--senginsemai--hafizin_kabri--munir_nurettin_selcuk
# iso-8859-1	saba--nakis--yuruksemai--ey_bad-i--suphi_ziya_ozbekkan
# iso-8859-1	mahur--sarki--aksak--alamam_dogrusu--serif_icli
# iso-8859-1	mahur--sarki--agiraksak--gulsen-i_ezhar--basmaci_abdi_efendi
# iso-8859-1	rast--sarki--yuruksemai--fitneler_gizlemis--mahmut_celalettin_pasa
# iso-8859-1	rast--sarki--agiraksak--cevr_olur--serif_icli
# iso-8859-1	hicazkar--sarki--oynak--cicekler_derleyeyim--muzaffer_ilkar
# iso-8859-1	buselik--sarki--aksak--bir_pur_cefa--iii._selim
# iso-8859-1	hicaz--sarki--duyek--kederden_mi--udi_mehmet_bey
# iso-8859-1	kurdilihicazkar--sarki--aksak--safvet-i_askim--sevki_bey
# iso-8859-1	kurdilihicazkar--pesrev--agirduyek----vasilaki
# iso-8859-1	mahur--sarki--musemmen--gosterip_agyare--haci_arif_bey
# iso-8859-1	beyati--pesrev--hafif----seyfettin_osmanoglu
# iso-8859-1	hicazkar--sarki--semai--yoktur_zaman--latif_aga
# iso-8859-1	acemasiran--sarki--sofyan--gonul_sana--sadettin_kaynak
# iso-8859-1	kurdilihicazkar--sarki--aksak--gun_dogmayacak--musa_sureyya_bey
# iso-8859-1	ussak--ilahi--duyek--dostun_senden--ali_rifat_cagatay
# iso-8859-1	mahur--sarki--senginsemai--hala_kanayan--yorgo_bacanos
# iso-8859-1	huzzam--agirsemai--agir_aksaksemai--kurban_olayim--haci_faik_bey
# iso-8859-1	beyati--agirsemai--aksaksemai--cikmaz_derun_u--tabi_mustafa_efendi
# iso-8859-1	muhayyer--sarki--senginsemai--pur-lerze--tanburi_cemil_bey
# iso-8859-1	rast--ilahi--evsat--ya_rabbi--ali_ufki
# iso-8859-1	rast--sarki--duyek--her_telden--sakir_aga
# iso-8859-1	ussak--sarki--aksak--siyah_ebrulerin--lemi_atli
# iso-8859-1	huzzam--sarki--aksaksemaievferi--kerem_eyle--medeni_aziz_efendi
# iso-8859-1	beyati--sarki--duyek--emel-i_meyl-i--sevki_bey
# iso-8859-1	mahur--sazsemaisi--aksaksemai----nikolaki
# iso-8859-1	muhayyer--sarki--aksak--serapa_husn--rahmi_bey
# iso-8859-1	mahur--pesrev--muhammes----tanburi_cemil_bey
# iso-8859-1	nihavent--sarki--senginsemai--bir_gun--musa_sureyya_bey
# iso-8859-1	kurdilihicazkar--sarki--aksak--safalar_getirdiniz--avni_anil
# iso-8859-1	segah--sarki--musemmen--gozlerinden_icti--sukru_erozan
# iso-8859-1	saba--sazsemaisi--aksaksemai----neyzen_aziz_dede
# iso-8859-1	buselik--pesrev--muhammes----nikolaki
# iso-8859-1	rast--medhal--hafif--musahabet_i_musikiye--refik_fersan
# iso-8859-1	saba--sarki--aksak--sen_sinemde--necip_mirkelamoglu
# iso-8859-1	huzzam--sarki--agiraksak--ey_sabah-i--leyla_saz
# iso-8859-1	kurdilihicazkar--fantezi--aksak--bugun_biz--neveser_kokdes
# iso-8859-1	kurdilihicazkar--sarki--curcuna--meftunun_oldum--ahmet_mithat_efendi
# iso-8859-1	acemasiran--sarki--aksak--dinle_sozum--iii._selim
# iso-8859-1	acemasiran--sarki--duyek--kime_halim--faize_ergin
# iso-8859-1	muhayyer--sazsemaisi--aksaksemai----tanburi_cemil_bey
# iso-8859-1	saba--sarki--senginsemai--sahilde_saba_ruzgari--mustafa_nafiz_irmak
# iso-8859-1	beyati--sarki--agiraksak--gul_hazin--rahmi_bey
# iso-8859-1	kurdilihicazkar--sarki--devrihindi--sen_beni--mahmud_celaleddin_pasa
# iso-8859-1	rast--sarki--curcuna--gamdan_azade--rifat_bey
# iso-8859-1	ussak--sarki--aksak--bag-i_husnun--kemal_emin_bara
# iso-8859-1	huzzam--sarki--semai--her_gece--kasim_inaltekin
# iso-8859-1	muhayyer--sarki--sofyan--ne_zaman--sadettin_kaynak
# iso-8859-1	muhayyer--pesrev--muhammes----kantemiroglu
# iso-8859-1	segah--sarki--senginsemai--ruhunda_olen--sadi_isilay
# iso-8859-1	huseyni--turku--sofyan--su_daglari--fahri_kayahan
# iso-8859-1	nihavent--agirsemai--aksaksemai--seni_hukm-u--ismail_hakki_bey
# iso-8859-1	rast--sarki--musemmen--hab-gahi--giriftzen_asim_bey
# iso-8859-1	rast--sarki--duyek--senin_askinla_cakoldum--basmaci_abdi_efendi
# iso-8859-1	hicaz--sarki--aksaksemai--sezdim_dargin--rifat_ayaydin
# iso-8859-1	kurdilihicazkar--sarki--yuruksemai--ey_mutrib-i--rahmi_bey
# iso-8859-1	mahur--sazsemaisi--aksaksemai----refik_talat_alpman
# iso-8859-1	huzzam--sarki--turkaksagi--bahar_oldu--seyh_ethem_efendi
# iso-8859-1	muhayyer--sarki--aksak--her_halinle--erol_sayan
# iso-8859-1	buselik--yuruksemai--yuruksemai--dehr_olmada--dede_efendi
# iso-8859-1	saba--tavsanca--semai--gelmis_degil--sakir_aga
# iso-8859-1	hicaz--beste--lenkfahte--baktikca_husn_u--suphi_ezgi
# iso-8859-1	ussak--ilahi--sofyan--hak_taala--ali_ufki
# iso-8859-1	saba--sarki--turkaksagi--dus_ben_gibi--serif_icli
# iso-8859-1	muhayyer--pesrev--devrikebir----tanburi_cemil_bey
# iso-8859-1	muhayyer--sarki--aksak--gunes_gibi--sadettin_kaynak
# iso-8859-1	muhayyer--sarki--duyek--cile_bulbulum--sadettin_kaynak
# iso-8859-1	hicaz--sarki--nimsofyan--yar_saclari--yesari_asim_arsoy
# iso-8859-1	huseyni--sarki--devrihindi--dil-rubasin_sevdigim--hafiz_esref_efendi
# iso-8859-1	huzzam--sarki--curcuna--mahzun_gonul--kemani_salih_efendi
# iso-8859-1	kurdilihicazkar--pesrev--muhammes----tanburi_cemil_bey
# iso-8859-1	saba--pesrev--duyek----tabi
# iso-8859-1	mahur--sarki--aksak--servinazi_seyret--rahmi_bey
# iso-8859-1	segah--pesrev--devrikebir----nayi_osman_dede
# iso-8859-1	muhayyer--turku--musemmen--elma_attim--tunceli
# iso-8859-1	buselik--nakis--yuruksemai--cefasi_asika--dellalzade
# iso-8859-1	huzzam--sarki--senginsemai--sen_sanki_baharin--musa_sureyya_bey
# iso-8859-1	beyati--sarki--aksak--benzemez_kimse--fehmi_tokay
# iso-8859-1	beyati--sazsemaisi--aksaksemai----kanuni_omer_efendi
# iso-8859-1	mahur--sarki--aksak--bir_gonulde--mazhar_bey
# iso-8859-1	acemasiran--pesrev--devrikebir----neyzen_salih_dede
# iso-8859-1	hicaz--sarki--nimsofyan--cok_yasa--muhlis_sabahaddin
# iso-8859-1	huzzam--sarki--aksak--zamani_var_ki--klarnet_ibrahim_efendi
# iso-8859-1	mahur--pesrev--duyek----gazi_giray_han
# iso-8859-1	nihavent--sarki--aksak--kiz_sen--faize_ergin
# iso-8859-1	mahur--sarki--semai--asika_bagdat--munir_nurettin_selcuk
# iso-8859-1	mahur--sarki--evsat--sabah_olsun--ibrahim_aga
# iso-8859-1	acemasiran--sarki--aksak--gordum_seni--irfan_dogrusoz
# iso-8859-1	mahur--sarki--aksak--gonul_adli--dellalzade
# iso-8859-1	buselik--sarki--turkaksagi--dun_gece_sende--sakir_aga
# iso-8859-1	huzzam--sarki--agiraksak--bekledim_yillarca--rakim_elkutlu
# iso-8859-1	hicaz--sarki--curcuna--sislendi_hava--rifat_bey
# iso-8859-1	huseyni--sarki--duyek--her_seherde--nihat_adlim
# iso-8859-1	buselik--sarki--aksak--dil_sana--tanburi_isak
# iso-8859-1	muhayyer--sarki--aksak--iltimas_etmeye--haci_arif_bey
# iso-8859-1	hicaz--agirsemai--agirsenginsemai--guller_kizarir--ibrahim_aga
# iso-8859-1	kurdilihicazkar--sarki--curcuna--sana_ey--rahmi_bey
# iso-8859-1	kurdilihicazkar--sarki--agiraksak--ehl-i_askin--tatyos_efendi
# iso-8859-1	rast--sarki--semai--sevmek_seni--neveser_kokdes
# iso-8859-1	mahur--sarki--aksak--iki_gozum--kemal_emin_bara
# iso-8859-1	muhayyer--turku--duyek--iste_seni--sadettin_kaynak
# iso-8859-1	buselik--sarki--curcuna--aman_cana--fehmi_tokay
# iso-8859-1	nihavent--sarki--turkaksagi--korfezdeki_dalgin--osman_nihat_akin
# iso-8859-1	hicazkar--sarki--sofyan--ben_sozune--numan_aga
# iso-8859-1	segah--sarki--curcuna--hasta_kalbimde--kaptanzade_ali_riza_bey
# iso-8859-1	hicazkar--sarki--devrihindi--lezzet_almis--ahmet_mithat_bey
# iso-8859-1	mahur--sarki--duyek--petek_petek--erol_sayan
# iso-8859-1	nihavent--beste--lenkfahte--zulfun_gorenlerin--ali_rifat_bey
# iso-8859-1	huzzam--sarki--senginsemai--acmam_acamam--nasibin_mehmet_yuru
# iso-8859-1	kurdilihicazkar--sarki--curcuna--gurub_etti--haci_arif_bey
# iso-8859-1	saba--sarki--aksak--mey_icerken--sevki_bey
# iso-8859-1	mahur--pesrev--hafif----rauf_yekta
# iso-8859-1	mahur--sarki--duyek--ayrilik_ruzgari--kamuran_yarkin
# iso-8859-1	kurdilihicazkar--sarki--aksak--gidelim_goksuya--lavtaci_hristo
# iso-8859-1	nihavent--sarki--sofyan--gonlumle_oturdum--sekip_mahmut_bey
# iso-8859-1	beyati--sarki--devrihindi--nar-i_firkat--mahmut_celalettin_pasa
# iso-8859-1	kurdilihicazkar--sarki--senginsemai--her_tel--kaptanzade_aliriza_bey
# iso-8859-1	kurdilihicazkar--sarki--aksak--muntazir_tesrifine--haci_arif_bey
# iso-8859-1	buselik--sarki--semai--dil_bestenim--vecdi_seyhun
# iso-8859-1	hicaz--sarki--duyek--artik_bu--alaeddin_yavasca
# iso-8859-1	hicaz--sarki--semai--ey_mehlika--ismail_hakki_bey
# iso-8859-1	rast--sazsemaisi--aksaksemai----kantemiroglu
# iso-8859-1	kurdilihicazkar--sarki--agiraksak--koparan_sinemi--bimen_sen
# iso-8859-1	segah--sarki--nimsofyan--gel_gitme--kaptanzade
# iso-8859-1	huzzam--sarki--turkaksagi--baglandi_gonul--selanikli_ahmet_efendi
# iso-8859-1	acemasiran--zeybek--agiraksak--su_izmirin--tahsin_karakus
# iso-8859-1	huseyni--sarki--agiraksak--firkat-i_canan--civan_aga
# iso-8859-1	hicazkar--sarki--duyek--cozmek_elinde--sadettin_kaynak
# iso-8859-1	hicazkar--sarki--aksak--bekledim_fecre--rakim_elkutlu
# iso-8859-1	mahur--tavsanca--aksak--nazar_etti--tanburi_mustafa_cavus
# iso-8859-1	mahur--sarki--curcuna--zahiri_hale--haci_arif_bey
# iso-8859-1	huseyni--sarki--aksak--sevdigim_cemalin--mahmut_celalettin_pasa
# iso-8859-1	muhayyer--sarki--yuruksemai--sevdicegim_asikini--dede_efendi
# iso-8859-1	mahur--sarki--aksak--ver_saki--refik_fersan
# iso-8859-1	mahur--sarki--duyek--saba_tarf-i--hafiz_husnu_efendi
# iso-8859-1	hicaz--sarki--curcuna--aksam_erdi--rahmi_bey
# iso-8859-1	nihavent--sarki--aksak--yok_baska--munir_nurettin_selcuk
# iso-8859-1	acemasiran--sazsemaisi--aksaksemai----udi_ibrahim_efendi
# iso-8859-1	hicaz--sarki--semai--sana_dun--munir_nurettin_selcuk
# iso-8859-1	hicaz--sarki--aksak--su_karsiki_dagda--dede_efendi
# iso-8859-1	mahur--sarki--sofyan--ne_dogan--munir_nurettin_selcuk
# iso-8859-1	acemasiran--sarki--yuruksemai--gel_ey_denizin--aleko_bacanos
# iso-8859-1	muhayyer--sarki--aksak--bir_gonulde--ahmet_rasim_bey
# iso-8859-1	rast--sarki--aksak--bin_can_ile--tanburi_buyuk_osman_bey
# iso-8859-1	acemasiran--sarki--sofyan--bakma_sakin--sakir_aga
# iso-8859-1	nihavent--fantezi--nimsofyan--benim_gonlum--kaptanzade
# iso-8859-1	mahur--sarki--aksak--su_guzele--semseddin_ziya_bey
# iso-8859-1	segah--sarki--devrihindi--dil_harab-i--tanburi_ali_efendi
# iso-8859-1	acemasiran--sarki--agiraksak--bir_haber--bimen_sen
# iso-8859-1	ussak--sarki--curcuna--cana_rakibi--giriftzen_asim_bey
# iso-8859-1	huseyni--sarki--curcuna--bak_su--danbeni_riza_bey
# iso-8859-1	huzzam--sarki--senginsemai--hal-i_dil-i--haci_arif_bey
# iso-8859-1	hicazkar--beste--yuruksemai--bulbul_gibi--zekai_dede
# iso-8859-1	rast--sarki--duyek--bir_gonul--ferit_sidal
# iso-8859-1	kurdilihicazkar--sarki--aydin--gozlerin_mavi--refik_fersan
# iso-8859-1	nihavent--sarki--duyek--unutturamaz_seni--ekrem_guyer
# iso-8859-1	muhayyer--sarki--aksak--humari_yok--haci_arif_bey
# iso-8859-1	mahur--sarki--duyek--ben_guzele--sadettin_kaynak
# iso-8859-1	segah--ilahi--sofyan--sordum_sari--
# iso-8859-1	huseyni--beste--duyek--muheyya_oldu--rakim_elkutlu
# iso-8859-1	rast--yuruksemai--yuruksemai--gelse_o_suh--hafiz_post
# iso-8859-1	nihavent--sarki--curcuna--guzel_bir--osman_nihat_akin
# iso-8859-1	ussak--pesrev--cenber----zurnazen_ibrahim_aga
# iso-8859-1	hicazkar--sarki--curcuna--senelerce--sabri_suha_ansen
# iso-8859-1	huzzam--sarki--aksak--gonlum_seher--sadettin_kaynak
# iso-8859-1	huseyni--agirsemai--aksaksemai--talatin_devri--zaharya
# iso-8859-1	muhayyer--sarki--aksaksemai--gun_kavustu--udi_nevres_bey
# iso-8859-1	hicaz--sarki--turkaksagi--ey_cerhi_sitemger--medeni_aziz_efendi
# iso-8859-1	mahur--yuruksemai--yuruksemai--yine_zevrak-i--dede_efendi
# iso-8859-1	rast--sarki--yuruksemai--sevdim_yine--basmaci_abdi_efendi
# iso-8859-1	segah--sarki--murekkepnimsofyan--dustu_enginlere--refik_fersan
# iso-8859-1	saba--ilahi--duyek--git_ey--munir_nurettin_selcuk
# iso-8859-1	muhayyer--sarki--sofyan--nicin_mahzun--haci_arif_bey
# iso-8859-1	mahur--mars--nimhafif--vur_pence-i--munir_nurettin_selcuk
# iso-8859-1	huseyni--sarki--aksak--varalim_kuy-i--munir_nurettin_selcuk
# iso-8859-1	hicaz--sarki--turkaksagi--solsan_da_sararsan--misirli_ibrahim
# iso-8859-1	huzzam--sarki--aksak--adanin_yesil_camlari--sukru_tunar
# iso-8859-1	beyati--sarki--aksak--ne_semtden--kemani_riza_efendi
# iso-8859-1	rast--sarki--sofyan--karli_dagi--rifat_bey
# iso-8859-1	huseyni--sarki--curcuna--nedir_bu_haletin--sevki_bey
# iso-8859-1	hicaz--sarki--duyek--yalan_degil--yusuf_nalkesen
# iso-8859-1	acemasiran--sarki--agiraksak--goncasindan_gulsenin--emin_ongan
# iso-8859-1	muhayyer--sarki--curcuna--batan_gun--sadettin_kaynak
# iso-8859-1	nihavent--sarki--duyek--askimin_ilk--arif_sami_toker
# iso-8859-1	kurdilihicazkar--sarki--aksak--nicin_terkeyleyip--haci_arif_bey
# iso-8859-1	beyati--sarki--ciftesofyan--cikalim_sayd_u--tanburi_mustafa_cavus
# iso-8859-1	hicaz--sarki--aksak--gulsen-i_husnune--rifat_bey
# iso-8859-1	rast--sarki--curcuna--anlatayim_halimi--tanburi_ali_efendi
# iso-8859-1	huzzam--sarki--aksak--ettigin_cevri--cinucen_tanrikorur
# iso-8859-1	acemasiran--sarki--aksak--oldu_gonul--dede_efendi
# iso-8859-1	hicaz--sarki--curcuna--anlatilmaz_bin--erdogan_yildizel
